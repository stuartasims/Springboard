# %% [markdown]
# # Monarch Reflectance Data Cleaning
#
# #### Purpose: prepare monarch reflectance data for analysis

# %%
#import tools for data cleaning
import pandas as pd
import numpy as np

# %%
#read in the dataset of reflectance across wavelengths
reflectance = pd.read_csv('../../data/input/monarch_reflectance.csv')  #

#visual inspection
print(reflectance.head(20))
# Out:
#    ORIGINAL DATA SCAN # RECORDED SCAN # Monarch                   Group Sex  \
# 0                   NaN             NaN     290    SUMMER BREEDING MALE   M
# 1                   NaN             NaN     294  SUMMER BREEDING FEMALE   F
# 2                   NaN             NaN     285    SUMMER BREEDING MALE   M
# 3                   NaN             NaN     276    SUMMER BREEDING MALE   M
# 4                   NaN             NaN     291  SUMMER BREEDING FEMALE   F
# 5                   NaN             NaN     282  SUMMER BREEDING FEMALE   F
# 6                   NaN             NaN     274  SUMMER BREEDING FEMALE   F
# 7                   NaN             NaN     128  SUMMER BREEDING FEMALE   F
# 8                   NaN             NaN     164  SUMMER BREEDING FEMALE   F
# 9                   NaN             NaN     179  SUMMER BREEDING FEMALE   F
# 10                  NaN             NaN    OH65            MIGRANT MALE   M
# 11                  NaN             NaN   OH116            MIGRANT MALE   M
# 12                  NaN             NaN    OH99            MIGRANT MALE   M
# 13                  NaN             NaN   OH103            MIGRANT MALE   M
# 14                  NaN             NaN   OH113            MIGRANT MALE   M
# 15                  NaN             NaN    OH79            MIGRANT MALE   M
# 16                  NaN             NaN    OH86            MIGRANT MALE   M
# 17                  NaN             NaN     T86            MIGRANT MALE   M
# 18                  NaN             NaN     T66            MIGRANT MALE   M
# 19                  NaN             NaN     T93            MIGRANT MALE   M
#
#     INFO  INFECTED  NOTES      338.9      340.4  ...     2498.2     2500.3  \
# 0    NaN       0.0    NaN   7.622500   7.537500  ...   9.620000   9.612500
# 1    NaN       0.0    NaN   7.160000   6.977500  ...  18.572500  18.545000
# 2    NaN       0.0    NaN   9.723333   9.703333  ...  14.566667  14.550000
# 3    NaN       0.0    NaN  10.000000  10.113333  ...  18.023333  18.006667
# 4    NaN       0.0    NaN   6.903333   6.786667  ...  15.706667  15.683333
# 5    NaN       0.0    NaN   6.666667   6.446667  ...  11.993333  11.980000
# 6    NaN       0.0    NaN   9.583333   9.156667  ...  16.540000  16.523333
# 7    NaN       0.0    NaN   6.550000   6.360000  ...  12.785000  12.752500
# 8    NaN       0.0    NaN   7.500000   8.200000  ...  21.493333  21.450000
# 9    NaN       0.0    NaN   8.056667   8.336667  ...  15.866667  15.836667
# 10   NaN       0.0    NaN   7.323333   7.203333  ...  22.236667  22.223333
# 11   NaN       0.0    NaN   9.860000   9.156667  ...  24.193333  24.190000
# 12   NaN       0.0    NaN   9.446667   9.293333  ...  22.346667  22.320000
# 13   NaN       0.0    NaN   7.666667   7.566667  ...  17.683333  17.650000
# 14   NaN       0.0    NaN   7.190000   6.826667  ...  14.420000  14.426667
# 15   NaN       0.0    NaN   8.886667   9.020000  ...  19.973333  19.963333
# 16   NaN       0.0    NaN  10.696667  10.523333  ...  24.836667  24.796667
# 17   NaN       0.0    NaN   9.166667   8.610000  ...  20.030000  19.976667
# 18   NaN       0.0    NaN   7.500000   7.653333  ...  18.450000  18.440000
# 19   NaN       0.0    NaN   7.660000   7.950000  ...  18.870000  18.866667
#
#        2502.4     2504.6     2506.7     2508.9       2511     2513.1  \
# 0    9.607500   9.577500   9.580000   9.562500   9.552500   9.562500
# 1   18.492500  18.447500  18.457500  18.457500  18.437500  18.410000
# 2   14.560000  14.540000  14.526667  14.513333  14.486667  14.500000
# 3   17.930000  17.880000  17.853333  17.840000  17.803333  17.783333
# 4   15.653333  15.623333  15.616667  15.590000  15.600000  15.580000
# 5   11.983333  11.970000  11.963333  11.970000  11.966667  11.980000
# 6   16.496667  16.473333  16.466667  16.476667  16.463333  16.440000
# 7   12.727500  12.712500  12.702500  12.692500  12.692500  12.695000
# 8   21.416667  21.380000  21.410000  21.420000  21.423333  21.380000
# 9   15.826667  15.776667  15.750000  15.756667  15.760000  15.740000
# 10  22.253333  22.250000  22.210000  22.216667  22.223333  22.260000
# 11  24.190000  24.180000  24.156667  24.170000  24.160000  24.150000
# 12  22.316667  22.303333  22.286667  22.313333  22.303333  22.290000
# 13  17.646667  17.650000  17.646667  17.650000  17.656667  17.636667
# 14  14.460000  14.476667  14.450000  14.433333  14.416667  14.440000
# 15  19.990000  19.953333  19.926667  19.950000  19.976667  19.950000
# 16  24.813333  24.826667  24.793333  24.773333  24.810000  24.786667
# 17  19.953333  19.936667  19.916667  19.900000  19.910000  19.920000
# 18  18.443333  18.430000  18.423333  18.440000  18.473333  18.450000
# 19  18.890000  18.870000  18.816667  18.860000  18.886667  18.890000
#
#        2515.3     2517.4
# 0    9.570000   9.622500
# 1   18.400000  18.430000
# 2   14.520000  14.543333
# 3   17.790000  17.826667
# 4   15.586667  15.636667
# 5   11.966667  11.970000
# 6   16.446667  16.496667
# 7   12.692500  12.712500
# 8   21.313333  21.370000
# 9   15.740000  15.733333
# 10  22.260000  22.263333
# 11  24.110000  24.190000
# 12  22.256667  22.283333
# 13  17.606667  17.590000
# 14  14.446667  14.423333
# 15  19.883333  19.903333
# 16  24.720000  24.833333
# 17  19.880000  19.913333
# 18  18.430000  18.490000
# 19  18.856667  18.896667
#
# [20 rows x 1002 columns]

# %% [markdown]
# #### the dataset contains several features that we actually wont use in this analysis:
# - ORIGINAL DATA SCAN #
# - RECORDED SCAN #
# - Monarch
# - Group
# - INFO
# - INFECTED
# - NOTES
#
# #### those features are then removed using df.drop()

# %%
#narrow the dataset to the categorical field for sex and the reflectance data.
reflectances = reflectance[reflectance['Group'] != 'ORIENTATION TEST']
reflectances = reflectances.drop([
    'ORIGINAL DATA SCAN #', 'RECORDED SCAN #', 'Monarch', 'Group', 'INFO',
    'INFECTED', 'NOTES'],axis=1)

reflectances.sample(10)
# Out:
#     Sex      338.9      340.4      341.9     343.5       345     346.5  \
# 38    M   8.700000   8.333333   7.753333  7.350000  6.910000  6.513333
# 31  NaN   4.085000   4.362500   4.140000  3.912500  4.167500  4.260000
# 3     M  10.000000  10.113333   9.636667  8.826667  8.216667  7.236667
# 22    M   9.583333   8.883333   8.460000  8.456667  7.983333  7.456667
# 72    F   7.630000   7.443333   7.310000  7.126667  6.666667  6.300000
# 42    M  11.396667  10.990000  10.646667  9.980000  9.350000  8.333333
# 70    F   7.703333   7.660000   7.413333  6.993333  6.150000  5.876667
# 7     F   6.550000   6.360000   6.182500  5.907500  5.597500  5.800000
# 41    M   9.556667   8.816667   8.220000  8.223333  7.620000  7.566667
# 66    F   8.050000   7.363333   6.986667  6.796667  6.763333  6.963333
#
#          348     349.5       351  ...     2498.2     2500.3     2502.4  \
# 38  6.093333  5.776667  5.426667  ...  19.670000  19.633333  19.626667
# 31  4.295000  4.305000  4.235000  ...   2.237500   2.242500   2.220000
# 3   6.726667  6.390000  6.123333  ...  18.023333  18.006667  17.930000
# 22  6.926667  6.480000  5.613333  ...  22.620000  22.603333  22.600000
# 72  6.236667  5.923333  5.686667  ...  14.476667  14.466667  14.493333
# 42  7.796667  7.180000  6.880000  ...  21.126667  21.093333  21.116667
# 70  5.956667  5.583333  5.543333  ...  14.926667  14.930000  14.896667
# 7   5.402500  5.052500  4.807500  ...  12.785000  12.752500  12.727500
# 41  7.260000  6.520000  5.960000  ...  16.440000  16.396667  16.390000
# 66  6.516667  5.980000  5.613333  ...  23.366667  23.360000  23.336667
#
#        2504.6     2506.7     2508.9       2511     2513.1     2515.3  \
# 38  19.606667  19.573333  19.563333  19.563333  19.536667  19.530000
# 31   2.235000   2.220000   2.242500   2.240000   2.280000   2.272500
# 3   17.880000  17.853333  17.840000  17.803333  17.783333  17.790000
# 22  22.616667  22.613333  22.603333  22.596667  22.600000  22.583333
# 72  14.476667  14.443333  14.440000  14.430000  14.423333  14.383333
# 42  21.110000  21.090000  21.086667  21.103333  21.093333  21.036667
# 70  14.880000  14.866667  14.866667  14.853333  14.840000  14.846667
# 7   12.712500  12.702500  12.692500  12.692500  12.695000  12.692500
# 41  16.383333  16.300000  16.256667  16.250000  16.233333  16.213333
# 66  23.336667  23.323333  23.320000  23.306667  23.290000  23.286667
#
#        2517.4
# 38  19.563333
# 31   2.290000
# 3   17.826667
# 22  22.583333
# 72  14.400000
# 42  21.076667
# 70  14.873333
# 7   12.712500
# 41  16.233333
# 66  23.313333
#
# [10 rows x 995 columns]

# %%
#### with the dataset now containing the reflectances at each wavelength, we need to check for any missing data

#sum of null values divided by non-null values per column, sorted top 10 values
print((reflectances.isnull().sum() /
       reflectances.isnull().count()).sort_values(ascending=False)[0:9])
# Out:
# Sex      0.030303
# 790.5    0.000000
# 807.1    0.000000
# 805.8    0.000000
# 804.5    0.000000
# 803.3    0.000000
# 802      0.000000
# 800.7    0.000000
# 799.5    0.000000
# dtype: float64

# %% [markdown]
# #### It looks like our label 'Sex' has some missing data (3% missing). That sex field contains the label we ultimately seek to classify. Records missing label values will be removed for the analysis

# %%
#drop rows with a null value in any field
reflectances = reflectances.dropna(axis=0)

#check for null values
print(reflectances.isnull().sum())

#check dimensions
print(reflectances.shape)
# Out:
# Sex       0
# 338.9     0
# 340.4     0
# 341.9     0
# 343.5     0
#          ..
# 2508.9    0
# 2511      0
# 2513.1    0
# 2515.3    0
# 2517.4    0
# Length: 995, dtype: int64
# (96, 995)

# %% [markdown]
# #### Now, the dataframe is complete and has no null values. The next step is to check for outliers in the reflectance fields

# %%
#mean-based outlier detection
#this assumes a normal distribution within each feature, so you could scale the data or pursue another method
from scipy import stats
features = reflectances.iloc[:, 1:]

z = np.abs(stats.zscore(features))
z_o = z[np.where(z > 3)]

#set an outlier threshold of 3 standard deviations from the mean
threshold = 3

#filter out any rows with a z score in a column above threshold
reflectances_sub_3z = reflectances[reflectances.iloc[:, 1:].apply(
    lambda x: np.abs(x - x.mean()) / x.std() < threshold).all(axis=1)]

# %%
#IQR-based outlier detection
thresh_25 = features.quantile(0.25)
thresh_75 = features.quantile(0.75)

#store IQR
iqr = abs(thresh_75 - thresh_25)

#determine outlier thresholds by multiplying iqr * 1.5 and adding to or subtracting from field mean
outlier_thresh_upper = (1.5*iqr)+thresh_75
outlier_thresh_lower = thresh_25 - (1.5*iqr)

# create mask to denote if each field value is an outlier or not
outlier_mask = ((features >=outlier_thresh_upper) | (features <= outlier_thresh_lower))

#fill with col mean?
features[~outlier_mask].fillna(features.mean())

#fill with median?
features[~outlier_mask].fillna(features.median())
# Out:
#         338.9      340.4     341.9     343.5       345     346.5       348  \
# 0    7.622500   7.537500  7.065000  6.560000  6.262500  5.820000  5.540000
# 1    7.160000   6.977500  6.850000  6.595000  6.420000  6.050000  5.675000
# 2    9.723333   9.703333  9.376667  8.823333  8.453333  8.223333  7.330000
# 3   10.000000  10.113333  9.636667  8.826667  8.216667  7.236667  6.726667
# 4    6.903333   6.786667  6.630000  6.163333  5.890000  5.780000  5.473333
# ..        ...        ...       ...       ...       ...       ...       ...
# 94   8.590000   8.306667  8.130000  7.726667  7.936667  7.340000  7.136667
# 95  10.693333   9.946667  9.376667  9.190000  9.523333  8.446667  8.333333
# 96   9.723333   9.276667  8.986667  8.453333  8.333333  7.890000  7.400000
# 97  10.556667  10.213333  9.900000  9.436667  9.046667  8.443333  8.230000
# 98   8.615000   8.395000  8.025000  7.538333  7.175000  6.850000  6.583333
#
#        349.5       351     352.5  ...     2498.2     2500.3     2502.4  \
# 0   5.150000  4.807500  4.772500  ...   9.620000   9.612500   9.607500
# 1   5.125000  4.845000  4.642500  ...  18.572500  18.545000  18.492500
# 2   7.223333  6.716667  6.746667  ...  14.566667  14.550000  14.560000
# 3   6.390000  6.123333  6.270000  ...  18.023333  18.006667  17.930000
# 4   5.220000  5.050000  4.810000  ...  15.706667  15.683333  15.653333
# ..       ...       ...       ...  ...        ...        ...        ...
# 94  6.576667  6.136667  5.906667  ...  25.526667  25.530000  25.483333
# 95  7.850000  7.620000  7.333333  ...  17.723333  17.740000  17.726667
# 96  6.786667  6.360000  6.250000  ...  14.400000  14.400000  14.370000
# 97  7.946667  7.440000  7.166667  ...  16.356667  16.350000  16.320000
# 98  6.108333  5.706667  5.431667  ...  18.397500  18.410000  18.380000
#
#        2504.6     2506.7     2508.9       2511     2513.1     2515.3  \
# 0    9.577500   9.580000   9.562500   9.552500   9.562500   9.570000
# 1   18.447500  18.457500  18.457500  18.437500  18.410000  18.400000
# 2   14.540000  14.526667  14.513333  14.486667  14.500000  14.520000
# 3   17.880000  17.853333  17.840000  17.803333  17.783333  17.790000
# 4   15.623333  15.616667  15.590000  15.600000  15.580000  15.586667
# ..        ...        ...        ...        ...        ...        ...
# 94  25.500000  25.523333  25.486667  25.470000  25.493333  25.543333
# 95  17.700000  17.700000  17.693333  17.686667  17.680000  17.690000
# 96  14.363333  14.390000  14.380000  14.360000  14.380000  14.406667
# 97  16.350000  16.383333  16.393333  16.390000  16.366667  16.356667
# 98  18.360000  18.360000  18.382500  18.350000  18.300000  18.347500
#
#        2517.4
# 0    9.622500
# 1   18.430000
# 2   14.543333
# 3   17.826667
# 4   15.636667
# ..        ...
# 94  25.520000
# 95  17.730000
# 96  14.430000
# 97  16.413333
# 98  18.455000
#
# [96 rows x 994 columns]

# %% [markdown]
# -----
#
# ##### While I could export the data with outliers transformed, the random forest approach is not as sensitive to outliers so I chose to leave them for the modeling stage
#
# -----

# %%
#While we could use the methods with outliers filtered out, the analysis, random forest, is robust to outliers
#therefor
reflectances.to_csv('../../data/input/reflectances_cleaned.csv', index=False)
